# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafiy27/Pemrosesan-Citra-Digital/blob/main/Assignment_4_PCD_1301204352_Muhammad_Rafi_Yanaputeranto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Referensi
# Sumber: Romindo and N. Khairina, “Analisa Perbandingan Metode Edge Detection Roberts Dan Prewitt,” Seminar Nasional Teknologi Informatika, pp. 244–251, 2017.

# %% [markdown]
# # Import Library

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Fungsi-fungsi yang digunakan

# %% [markdown]
# ## Konversi Citra ke grayscale

# %%
def rgb_to_gray(rgb_image):
    return cv2.cvtColor(rgb_image, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# ## Metode Roberts

# %%
# Fungsi untuk deteksi tepi dengan metode Roberts
def roberts_edge_detection(image):
    # Kernel Roberts
    kernel_x = np.array([[1, 0], [0, -1]])
    kernel_y = np.array([[0, 1], [-1, 0]])

    # Konvolusi dengan kernel horizontal dan vertikal
    grad_x = cv2.filter2D(image, -1, kernel_x)
    grad_y = cv2.filter2D(image, -1, kernel_y)

    # Gradien total
    gradient = np.sqrt(grad_x**2 + grad_y**2)

    return gradient

# %% [markdown]
# ## Metode Pretwit

# %%
# Fungsi untuk deteksi tepi dengan metode Prewitt
def prewitt_edge_detection(image):
    # Kernel Prewitt
    kernel_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])
    kernel_y = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]])

    # Konvolusi dengan kernel horizontal dan vertikal
    grad_x = cv2.filter2D(image, -1, kernel_x)
    grad_y = cv2.filter2D(image, -1, kernel_y)

    # Gradien total
    gradient = np.sqrt(grad_x**2 + grad_y**2)

    return gradient

# %% [markdown]
# # Program utama

# %%
# Baca gambar
image = cv2.imread('Gambar.jpg')

# Konversi ke grayscale
gray_image = rgb_to_gray(image)

# Deteksi tepi dengan metode Roberts
edges_roberts = roberts_edge_detection(gray_image)
# Deteksi tepi dengan metode Prewitt
edges_prewitt = prewitt_edge_detection(gray_image)

# Menampilkan hasil dalam plot
plt.figure(figsize=(10, 5))

plt.subplot(131)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Citra Asli')
plt.axis('off')

plt.subplot(132)
plt.imshow(edges_roberts, cmap='gray')
plt.title('Roberts Edge Detection')
plt.axis('off')

plt.subplot(133)
plt.imshow(edges_prewitt, cmap='gray')
plt.title('Prewitt Edge Detection')
plt.axis('off')

plt.show()
